# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
import os
os.environ["TAVILY_API_KEY"] = "tvXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'gemini version releases and updates from 2022 to 2026'})
results
# Out:
# [{'title': 'Release notes | Gemini API - Google AI for Developers',
#   'url': 'https://ai.google.dev/gemini-api/docs/changelog',
# ...

# %%
for r in results:
    print(r['content'])
# Out:
# ## March 11, 2025
#
# SDK updates:
#
#  Released the
#   Google Gen AI SDK for TypeScript and JavaScript
#   to public preview.
#
# ## March 7, 2025
#
# Model updates:
#
#  Released `gemini-embedding-exp-03-07`, an
#   experimental
#   Gemini-based embeddings model in public preview.
#
# ## February 28, 2025
#
# API updates:
#
#  Support for Search as a tool
#   added to `gemini-2.0-pro-exp-02-05`, an experimental model based on
#   Gemini 2.0 Pro.
#
# ## February 25, 2025
#
# Model updates:
#
#  Released `gemini-2.0-flash-lite`, a generally available (GA) version of
#   Gemini 2.0 Flash-Lite,
#   which is optimized for speed, scale, and cost efficiency.
#
# ## February 19, 2025
#
# AI Studio updates:
#
#  Support for
#   additional regions
#   (Kosovo, Greenland and Faroe Islands).
#
# API updates: [...] ## April 4, 2025
#
#  Released `gemini-2.5-pro-preview-03-25`, a public preview Gemini 2.5 Pro version
# ...
